# %% [markdown]
# # Introduction to Data Science
# ## Lab 4: Intro to Regular Expressions

# %% [markdown]
# 1\. I realize that question 2 on the homework might be a little difficult; let's walk through the problem

# %%
import re # you might find this package useful

contributors = dict()

# Read through each line of the data
f = open("/Users/ruojunhong/Desktop/DataScienceCourse/ipython/data/osquery_contributors.html", "r")

# %%
for line in f:
    print(line)
# Out:
# <!DOCTYPE html>
#
# <html class="" lang="en">
#
# <head prefix="og: http://ogp.me/ns# fb: http://ogp.me/ns/fb# object: http://ogp.me/ns/object# article: http://ogp.me/ns/article# profile: http://ogp.me/ns/profile#">
#
# <meta charset="utf-8">
#
# <meta content="IE=edge" http-equiv="X-UA-Compatible">
#
# <meta content="en" http-equiv="Content-Language">
#
# <meta content="width=1020" name="viewport">
#
# <title>Contributors to facebook/osquery</title>
#
# <link title="GitHub" href="/opensearch.xml" type="application/opensearchdescription+xml" rel="search">
#
# <link title="GitHub" href="https://github.com/fluidicon.png" rel="fluid-icon">
#
# <link href="/apple-touch-icon-114.png" sizes="57x57" rel="apple-touch-icon">
#
# <link href="/apple-touch-icon-114.png" sizes="114x114" rel="apple-touch-icon">
#
# <link href="/apple-touch-icon-144.png" sizes="72x72" rel="apple-touch-icon">
#
# <link href="/apple-touch-icon-144.png" sizes="144x144" rel="apple-touch-icon">
#
# <meta content="1401488693436528" property="fb:app_id">
#
# <meta name="twitter:site" content="@github">
#
# <meta name="twitter:card" content="summary">
#
# <meta name="twitter:title" content="facebook/osquery">
#
# <meta name="twitter:description" content="osquery - SQL powered operating system instrumentation, monitoring, and analytics.">
#
# <meta name="twitter:image:src" content="https://avatars2.githubusercontent.com/u/69631?v=3&s=400">
#
# <meta property="og:site_name" content="GitHub">
#
# <meta property="og:type" content="object">
#
# <meta property="og:image" content="https://avatars2.githubusercontent.com/u/69631?v=3&s=400">
#
# <meta property="og:title" content="facebook/osquery">
#
# <meta property="og:url" content="https://github.com/facebook/osquery">
#
# <meta property="og:description" content="osquery - SQL powered operating system instrumentation, monitoring, and analytics.">
#
# <meta content="https://api.github.com/_private/browser/stats" name="browser-stats-url">
#
# <meta content="https://api.github.com/_private/browser/errors" name="browser-errors-url">
#
# <link href="https://assets-cdn.github.com/" rel="assets">
#
# <link href="wss://live.github.com/_sockets/MjExNzgxMzo0ZTA5ZDRlZjk5MGFlZGZlNTFmOWNkMzRiYjZkZjljOTpmN2E1Y2ExODY1ZjE5NTg5YTliOTRmNGFiMDhhOGMxODA1ZTA4MmI4YThlN2FmZTVlN2UxYjcwMTIyNjAyZGY4--341400ccc9bfdf3806ccde11f3eb3c9350824729" rel="web-socket">
#
# <meta content="1000" name="pjax-timeout">
#
# <link href="/sessions/sudo_modal" rel="sudo-modal">
#
# <meta content="/windows-tile.png" name="msapplication-TileImage">
#
# <meta content="#ffffff" name="msapplication-TileColor">
#
# <meta content="KT5gs8h0wvaagLKAVWq8bbeNwnZZK1r1XQysX3xurLU" name="google-site-verification">
#
# <meta content="UA-3769691-2" name="google-analytics">
#
# <meta name="octolytics-host" content="collector.githubapp.com">
#
# <meta name="octolytics-script-host" content="collector-cdn.github.com">
#
# <meta name="octolytics-app-id" content="github">
#
# <meta name="octolytics-dimension-request_id" content="6C3C8DB2:7F5C:70FC4F2:55EF35B7">
#
# <meta name="octolytics-actor-id" content="2117813">
#
# <meta name="octolytics-actor-login" content="rmoakler">
#
# <meta name="octolytics-actor-hash" content="5da497be1e468ec661373f6bf1fa36dfd0c0486b0adab36c2b6aab8d2c0db4fc">
#
# <meta class="js-ga-set" content="Logged In" name="dimension1">
#
# <meta class="js-ga-set" content="Current repo nav" name="dimension4">
#
# <meta content="true" name="is-dotcom">
#
# <meta content="github.com" name="hostname">
#
# <meta content="rmoakler" name="user-login">
#
# <link color="#4078c0" href="https://assets-cdn.github.com/pinned-octocat.svg" rel="mask-icon">
#
# <link href="https://assets-cdn.github.com/favicon.ico" type="image/x-icon" rel="icon">
#
# <meta name="csrf-param" content="authenticity_token">
#
# <meta name="csrf-token" content="1uoMgtWD9sBaQfbbyqNQPnQYOwa9tzr8IX/xhmwNZ88ThL8b3CdxsQb9dv2X6NWDuAgzGZUc8WbbxPidrkmatg==">
#
# <meta name="form-nonce" content="6c29b689486a15ac6a50719013b85362efbebad2">
#
# <link rel="stylesheet" media="all" href="https://assets-cdn.github.com/assets/github-297f62b515917a9f8880b23160a0cb5073573d140c9fa1b8c36c54eef056537d.css" crossorigin="anonymous">
#
# <link rel="stylesheet" media="all" href="https://assets-cdn.github.com/assets/github2-c886ea113dfefe6682bd6ebf7c7256580ff2125a1f8c584a26ceffea4eafde72.css" crossorigin="anonymous">
#
# <meta content="916f2bb26096d019174bf47fc02dfd26" http-equiv="x-pjax-version">
#
# <meta content="osquery - SQL powered operating system instrumentation, monitoring, and analytics." name="description">
#
# <meta content="github.com/facebook/osquery git https://github.com/facebook/osquery.git" name="go-import">
#
# <meta name="octolytics-dimension-user_id" content="69631">
#
# <meta name="octolytics-dimension-user_login" content="facebook">
#
# <meta name="octolytics-dimension-repository_id" content="22394357">
#
# <meta name="octolytics-dimension-repository_nwo" content="facebook/osquery">
#
# <meta name="octolytics-dimension-repository_public" content="true">
#
# <meta name="octolytics-dimension-repository_is_fork" content="false">
#
# <meta name="octolytics-dimension-repository_network_root_id" content="22394357">
#
# <meta name="octolytics-dimension-repository_network_root_nwo" content="facebook/osquery">
#
# <link type="application/atom+xml" title="Recent Commits to osquery:master" rel="alternate" href="https://github.com/facebook/osquery/commits/master.atom">
#
# <script type="text/javascript" async="" src="//collector-cdn.github.com/assets/api.js">
#
# <script src="https://assets-cdn.github.com/assets/graph-lib-9e696042b12555476aef9e6fe1d27200f9606593462e508d1228437ba052a6f3.js">
#
# <meta value="repo_graphs" name="selected-link" data-pjax-transient="true">
#
# <meta name="analytics-event" data-pjax-transient="true" content="Rails, view, graphs#contributors">
#
# </head>
#
# <body class="logged_in env-production macintosh vis-public">
#
# <a class="accessibility-aid js-skip-to-content" tabindex="1" href="#start-of-content">Skip to content</a>
#
# <div class="header header-logged-in true" role="banner">
#
# <div class="container clearfix">
#
# <a class="header-logo-invertocat" data-ga-click="Header, go to dashboard, icon:logo" aria-label="Homepage" data-hotkey="g d" href="https://github.com/">
#
# <span class="mega-octicon octicon-mark-github"></span>
#
# </a>
#
# <div class="site-search repo-scope js-site-search" role="search">
#
# <form class="js-site-search-form" method="get" data-repo-search-url="/facebook/osquery/search" data-global-search-url="/search" action="/facebook/osquery/search" accept-charset="UTF-8">
#
# <div style="margin:0;padding:0;display:inline">
#
# <input type="hidden" value="✓" name="utf8">
#
# </div>
#
# <label class="js-chromeless-input-container form-control">
#
# <div class="scope-badge">This repository</div>
#
# <input class="js-site-search-focus js-site-search-field is-clearable chromeless-input" type="text" autocapitalize="off" tabindex="1" data-repo-scope-placeholder="Search" data-global-scope-placeholder="Search GitHub" aria-label="Search this repository" placeholder="Search" name="q" data-hotkey="s">
#
# </label>
#
# </form>
#
# </div>
#
# <ul class="header-nav left" role="navigation">
#
# <li class="header-nav-item">
#
# <a class="js-selected-navigation-item header-nav-link" data-selected-links="/pulls /pulls/assigned /pulls/mentioned /pulls" data-hotkey="g p" data-ga-click="Header, click, Nav menu - item:pulls context:user" href="/pulls"> Pull requests </a>
#
# </li>
#
# <li class="header-nav-item">
#
# <a class="js-selected-navigation-item header-nav-link" data-selected-links="/issues /issues/assigned /issues/mentioned /issues" data-hotkey="g i" data-ga-click="Header, click, Nav menu - item:issues context:user" href="/issues"> Issues </a>
#
# </li>
#
# <li class="header-nav-item">
#
# <a class="header-nav-link" data-ga-click="Header, go to gist, text:gist" href="https://gist.github.com/">Gist</a>
#
# </li>
#
# </ul>
#
# <ul id="user-links" class="header-nav user-nav right">
#
# <li class="header-nav-item">
#
# <span class="js-socket-channel js-updatable-content" data-url="/notifications/header" data-channel="notification-changed:rmoakler">
#
# <a class="header-nav-link notification-indicator tooltipped tooltipped-s" data-hotkey="g n" data-ga-click="Header, go to notifications, icon:read" aria-label="You have no unread notifications" href="/notifications">
#
# <span class="mail-status all-read"></span>
#
# <span class="octicon octicon-bell"></span>
#
# </a>
#
# </span>
#
# </li>
#
# <li class="header-nav-item dropdown js-menu-container">
#
# <a class="header-nav-link tooltipped tooltipped-s js-menu-target" data-ga-click="Header, create new, icon:add" aria-label="Create new…" href="/new">
#
# <span class="octicon octicon-plus left"></span>
#
# <span class="dropdown-caret"></span>
#
# </a>
#
# <div class="dropdown-menu-content js-menu-content">
#
# <ul class="dropdown-menu dropdown-menu-sw">
#
# <a class="dropdown-item" data-ga-click="Header, create new repository" href="/new"> New repository </a>
#
# <a class="dropdown-item" data-ga-click="Header, create new organization" href="/organizations/new"> New organization </a>
#
# <div class="dropdown-divider"></div>
#
# <div class="dropdown-header">
#
# <span title="facebook/osquery">This repository</span>
#
# </div>
#
# <a class="dropdown-item" data-ga-click="Header, create new issue" href="/facebook/osquery/issues/new"> New issue </a>
#
# </ul>
#
# </div>
#
# </li>
#
# <li class="header-nav-item dropdown js-menu-container">
#
# <a class="header-nav-link name tooltipped tooltipped-s js-menu-target" data-ga-click="Header, show menu, icon:avatar" aria-label="View profile and more" href="/rmoakler">
#
# <img class="avatar" width="20" height="20" src="https://avatars3.githubusercontent.com/u/2117813?v=3&s=40" alt="@rmoakler">
#
# <span class="dropdown-caret"></span>
#
# </a>
#
# <div class="dropdown-menu-content js-menu-content">
#
# <div class="dropdown-menu dropdown-menu-sw">
#
# <div class="dropdown-header header-nav-current-user css-truncate">
#
# Signed in as
#
# <strong class="css-truncate-target">rmoakler</strong>
#
# </div>
#
# <div class="dropdown-divider"></div>
#
# <a class="dropdown-item" data-ga-click="Header, go to profile, text:your profile" href="/rmoakler"> Your profile </a>
#
# <a class="dropdown-item" data-ga-click="Header, go to starred repos, text:your stars" href="/stars"> Your stars </a>
#
# <a class="dropdown-item" data-ga-click="Header, go to explore, text:explore" href="/explore"> Explore </a>
#
# <a class="dropdown-item" data-ga-click="Header, go to help, text:help" href="https://help.github.com"> Help </a>
#
# <div class="dropdown-divider"></div>
#
# <a class="dropdown-item" data-ga-click="Header, go to settings, icon:settings" href="/settings/profile"> Settings </a>
#
# <form class="logout-form" method="post" data-form-nonce="6c29b689486a15ac6a50719013b85362efbebad2" action="/logout" accept-charset="UTF-8">
#
# <div style="margin:0;padding:0;display:inline">
#
# <input type="hidden" value="✓" name="utf8">
#
# <input type="hidden" value="ySCmO2VfnFt1nwk9ZtdwuSFyzIqzSZl1n3p0ixPVHwaBBFm58K8Hj1JrFhYl1NA8WYxUTjmbkRDTSikO5aAGnA==" name="authenticity_token">
#
# </div>
#
# <button class="dropdown-item dropdown-signout" data-ga-click="Header, sign out, icon:logout"> Sign out </button>
#
# </form>
#
# </div>
#
# </div>
#
# </li>
#
# </ul>
#
# </div>
#
# </div>
#
# <div id="start-of-content" class="accessibility-aid"></div>
#
# <div id="js-flash-container"> </div>
#
# <div itemtype="http://schema.org/WebPage" itemscope="">
#
# <div class="pagehead repohead instapaper_ignore readability-menu">
#
# <div class="container">
#
# <div class="clearfix">
#
# <ul class="pagehead-actions">
#
# <li>
#
# <form class="js-social-container" method="post" data-remote="true" data-form-nonce="6c29b689486a15ac6a50719013b85362efbebad2" data-autosubmit="true" action="/notifications/subscribe" accept-charset="UTF-8">
#
# <div style="margin:0;padding:0;display:inline">
#
# <input type="hidden" value="✓" name="utf8">
#
# <input type="hidden" value="fx3dQjIOsKC2GXb9ePi0lEm96GYlFj6RIrMq9d7x1bREcUnuPo0Nj8SLW+wPmKsuI1CQ8TTXIh16SB5wHbqklw==" name="authenticity_token">
#
# </div>
#
# <input id="repository_id" type="hidden" value="22394357" name="repository_id">
#
# <div class="select-menu js-menu-container js-select-menu">
#
# <a class="btn btn-sm btn-with-count select-menu-button js-menu-target" data-ga-click="Repository, click Watch settings, action:graphs#contributors" aria-haspopup="true" tabindex="0" role="button" href="/facebook/osquery/subscription">
#
# <span class="js-select-button">
#
# <span class="octicon octicon-eye"></span>
#
# Watch
#
# </span>
#
# </a>
#
# <a class="social-count js-social-count" href="/facebook/osquery/watchers"> 338 </a>
#
# <div class="select-menu-modal-holder">
#
# <div class="select-menu-modal subscription-menu-modal js-menu-content" aria-hidden="true">
#
# <div class="select-menu-header">
#
# <span class="select-menu-title">Notifications</span>
#
# <span class="octicon octicon-x js-menu-close" aria-label="Close" role="button"></span>
#
# </div>
#
# <div class="select-menu-list js-navigation-container" role="menu">
#
# <div class="select-menu-item js-navigation-item selected" tabindex="0" role="menuitem">
#
# <span class="select-menu-item-icon octicon octicon-check"></span>
#
# <div class="select-menu-item-text">
#
# <input id="do_included" type="radio" value="included" name="do" checked="checked">
#
# <span class="select-menu-item-heading">Not watching</span>
#
# <span class="description">Be notified when participating or @mentioned.</span>
#
# <span class="js-select-button-text hidden-select-button-text">
#
# <span class="octicon octicon-eye"></span>
#
# Watch
#
# </span>
#
# </div>
#
# </div>
#
# <div class="select-menu-item js-navigation-item " tabindex="0" role="menuitem">
#
# <span class="select-menu-item-icon octicon octicon octicon-check"></span>
#
# <div class="select-menu-item-text">
#
# <input id="do_subscribed" type="radio" value="subscribed" name="do">
#
# <span class="select-menu-item-heading">Watching</span>
#
# <span class="description">Be notified of all conversations.</span>
#
# <span class="js-select-button-text hidden-select-button-text">
#
# <span class="octicon octicon-eye"></span>
#
# Unwatch
#
# </span>
#
# </div>
#
# </div>
#
# <div class="select-menu-item js-navigation-item " tabindex="0" role="menuitem">
#
# <span class="select-menu-item-icon octicon octicon-check"></span>
#
# <div class="select-menu-item-text">
#
# <input id="do_ignore" type="radio" value="ignore" name="do">
#
# <span class="select-menu-item-heading">Ignoring</span>
#
# <span class="description">Never be notified.</span>
#
# <span class="js-select-button-text hidden-select-button-text">
#
# <span class="octicon octicon-mute"></span>
#
# Stop ignoring
#
# </span>
#
# </div>
#
# </div>
#
# </div>
#
# </div>
#
# </div>
#
# </div>
#
# </form>
#
# </li>
#
# <li>
#
# <div class="js-toggler-container js-social-container starring-container ">
#
# <form class="js-toggler-form starred js-unstar-button" method="post" data-remote="true" data-form-nonce="6c29b689486a15ac6a50719013b85362efbebad2" action="/facebook/osquery/unstar" accept-charset="UTF-8">
#
# <div style="margin:0;padding:0;display:inline">
#
# <input type="hidden" value="✓" name="utf8">
#
# <input type="hidden" value="m5SFLQqNzfxZnohHGbB2GuX5N3Hpe7ZzDMYAxSbHiMy+zB30s41vJMkuOIkmeXfhZfG42dzFO0QyltqnSCjARw==" name="authenticity_token">
#
# </div>
#
# <button class="btn btn-sm btn-with-count js-toggler-target" data-ga-click="Repository, click unstar button, action:graphs#contributors; text:Unstar" title="Unstar facebook/osquery" aria-label="Unstar this repository">
#
# <span class="octicon octicon-star"></span>
#
# Unstar
#
# </button>
#
# <a class="social-count js-social-count" href="/facebook/osquery/stargazers"> 5,010 </a>
#
# </form>
#
# <form class="js-toggler-form unstarred js-star-button" method="post" data-remote="true" data-form-nonce="6c29b689486a15ac6a50719013b85362efbebad2" action="/facebook/osquery/star" accept-charset="UTF-8">
#
# <div style="margin:0;padding:0;display:inline">
#
# <input type="hidden" value="✓" name="utf8">
#
# <input type="hidden" value="JvCln4QDVcWipBZvx/BIRdZTjCfN+Mxw3uJdBElgxMcP1XiQsctgaG7aOyPjPmC+K/Xjo14Ye57j8JK+r1JMig==" name="authenticity_token">
#
# </div>
#
# <button class="btn btn-sm btn-with-count js-toggler-target" data-ga-click="Repository, click star button, action:graphs#contributors; text:Star" title="Star facebook/osquery" aria-label="Star this repository">
#
# <span class="octicon octicon-star"></span>
#
# Star
#
# </button>
#
# <a class="social-count js-social-count" href="/facebook/osquery/stargazers"> 5,010 </a>
#
# </form>
#
# </div>
#
# </li>
#
# <li>
#
# <a class="btn btn-sm btn-with-count" data-ga-click="Repository, show fork modal, action:graphs#contributors; text:Fork" rel="facebox" aria-label="Fork your own copy of facebook/osquery to your account" title="Fork your own copy of facebook/osquery to your account" href="#fork-destination-box">
#
# <span class="octicon octicon-repo-forked"></span>
#
# Fork
#
# </a>
#
# <a class="social-count" href="/facebook/osquery/network">443</a>
#
# <div id="fork-destination-box" style="display: none;">
#
# <h2 class="facebox-header" data-facebox-id="facebox-header">Where should we fork this repository?</h2>
#
# <include-fragment class="js-fork-select-fragment fork-select-fragment" data-url="/facebook/osquery/fork?fragment=1" src="">
#
# <img width="64" height="64" src="https://assets-cdn.github.com/images/spinners/octocat-spinner-128.gif" alt="Loading">
#
# </include-fragment>
#
# </div>
#
# </li>
#
# </ul>
#
# <h1 class="entry-title public " itemtype="http://data-vocabulary.org/Breadcrumb" itemscope="">
#
# <span class="mega-octicon octicon-repo"></span>
#
# <span class="author">
#
# <a class="url fn" rel="author" itemprop="url" href="/facebook">
#
# <span itemprop="title">facebook</span>
#
# </a>
#
# </span>
#
# <span class="path-divider">/</span>
#
# <strong>
#
# <a data-pjax="#js-repo-pjax-container" href="/facebook/osquery">osquery</a>
#
# </strong>
#
# <span class="page-context-loader">
#
# <img width="16" height="16" src="https://assets-cdn.github.com/images/spinners/octocat-spinner-32.gif" alt="">
#
# </span>
#
# </h1>
#
# </div>
#
# </div>
#
# </div>
#
# <div class="container">
#
# <div class="repository-with-sidebar repo-container new-discussion-timeline">
#
# <div class="repository-sidebar clearfix">
#
# <nav class="sunken-menu repo-nav js-repo-nav js-sidenav-container-pjax js-octicon-loaders" data-issue-count-url="/facebook/osquery/issues/counts" data-pjax="#js-repo-pjax-container" role="navigation">
#
# <ul class="sunken-menu-group">
#
# <li class="tooltipped tooltipped-w" aria-label="Code">
#
# <a class="js-selected-navigation-item sunken-menu-item" data-selected-links="repo_source repo_downloads repo_commits repo_releases repo_tags repo_branches /facebook/osquery" data-hotkey="g c" aria-label="Code" href="/facebook/osquery">
#
# <span class="octicon octicon-code"></span>
#
# <span class="full-word">Code</span>
#
# <img class="mini-loader" width="16" height="16" src="https://assets-cdn.github.com/images/spinners/octocat-spinner-32.gif" alt="">
#
# </a>
#
# </li>
#
# <li class="tooltipped tooltipped-w" aria-label="Issues">
#
# <a class="js-selected-navigation-item sunken-menu-item" data-selected-links="repo_issues repo_labels repo_milestones /facebook/osquery/issues" data-hotkey="g i" aria-label="Issues" href="/facebook/osquery/issues">
#
# <span class="octicon octicon-issue-opened"></span>
#
# <span class="full-word">Issues</span>
#
# <span class="js-issue-replace-counter"></span>
#
# <img class="mini-loader" width="16" height="16" src="https://assets-cdn.github.com/images/spinners/octocat-spinner-32.gif" alt="">
#
# </a>
#
# </li>
#
# <li class="tooltipped tooltipped-w" aria-label="Pull requests">
#
# <a class="js-selected-navigation-item sunken-menu-item" data-selected-links="repo_pulls /facebook/osquery/pulls" data-hotkey="g p" aria-label="Pull requests" href="/facebook/osquery/pulls">
#
# <span class="octicon octicon-git-pull-request"></span>
#
# <span class="full-word">Pull requests</span>
#
# <span class="js-pull-replace-counter"></span>
#
# <img class="mini-loader" width="16" height="16" src="https://assets-cdn.github.com/images/spinners/octocat-spinner-32.gif" alt="">
#
# </a>
#
# </li>
#
# <li class="tooltipped tooltipped-w" aria-label="Wiki">
#
# <a class="js-selected-navigation-item sunken-menu-item" data-selected-links="repo_wiki /facebook/osquery/wiki" data-hotkey="g w" aria-label="Wiki" href="/facebook/osquery/wiki">
#
# <span class="octicon octicon-book"></span>
#
# <span class="full-word">Wiki</span>
#
# <img class="mini-loader" width="16" height="16" src="https://assets-cdn.github.com/images/spinners/octocat-spinner-32.gif" alt="">
#
# </a>
#
# </li>
#
# </ul>
#
# <div class="sunken-menu-separator"></div>
#
# <ul class="sunken-menu-group">
#
# <li class="tooltipped tooltipped-w" aria-label="Pulse">
#
# <a class="js-selected-navigation-item sunken-menu-item" data-selected-links="pulse /facebook/osquery/pulse" aria-label="Pulse" href="/facebook/osquery/pulse">
#
# <span class="octicon octicon-pulse"></span>
#
# <span class="full-word">Pulse</span>
#
# <img class="mini-loader" width="16" height="16" src="https://assets-cdn.github.com/images/spinners/octocat-spinner-32.gif" alt="">
#
# </a>
#
# </li>
#
# <li class="tooltipped tooltipped-w" aria-label="Graphs">
#
# <a class="js-selected-navigation-item sunken-menu-item selected" data-selected-links="repo_graphs repo_contributors /facebook/osquery/graphs" aria-selected="true" aria-label="Graphs" href="/facebook/osquery/graphs">
#
# <span class="octicon octicon-graph"></span>
#
# <span class="full-word">Graphs</span>
#
# <img class="mini-loader" width="16" height="16" src="https://assets-cdn.github.com/images/spinners/octocat-spinner-32.gif" alt="">
#
# </a>
#
# </li>
#
# </ul>
#
# </nav>
#
# <div class="only-with-full-nav">
#
# <div class="js-clone-url clone-url " data-protocol-type="http">
#
# <h3>
#
# <span class="text-emphasized">HTTPS</span>
#
# clone URL
#
# </h3>
#
# <div class="input-group js-zeroclipboard-container">
#
# <input class="input-mini input-monospace js-url-field js-zeroclipboard-target" type="text" aria-label="HTTPS clone URL" readonly="readonly" value="https://github.com/facebook/osquery.git">
#
# <span class="input-group-button">
#
# <button class="js-zeroclipboard btn btn-sm zeroclipboard-button tooltipped tooltipped-s" type="button" data-copied-hint="Copied!" aria-label="Copy to clipboard">
#
# <span class="octicon octicon-clippy"></span>
#
# </button>
#
# </span>
#
# </div>
#
# </div>
#
# <div class="js-clone-url clone-url open" data-protocol-type="ssh">
#
# <h3>
#
# <span class="text-emphasized">SSH</span>
#
# clone URL
#
# </h3>
#
# <div class="input-group js-zeroclipboard-container">
#
# <input class="input-mini input-monospace js-url-field js-zeroclipboard-target" type="text" aria-label="SSH clone URL" readonly="readonly" value="git@github.com:facebook/osquery.git">
#
# <span class="input-group-button">
#
# <button class="js-zeroclipboard btn btn-sm zeroclipboard-button tooltipped tooltipped-s" type="button" data-copied-hint="Copied!" aria-label="Copy to clipboard">
#
# <span class="octicon octicon-clippy"></span>
#
# </button>
#
# </span>
#
# </div>
#
# </div>
#
# <div class="js-clone-url clone-url " data-protocol-type="subversion">
#
# <h3>
#
# <span class="text-emphasized">Subversion</span>
#
# checkout URL
#
# </h3>
#
# <div class="input-group js-zeroclipboard-container">
#
# <input class="input-mini input-monospace js-url-field js-zeroclipboard-target" type="text" aria-label="Subversion checkout URL" readonly="readonly" value="https://github.com/facebook/osquery">
#
# <span class="input-group-button">
#
# <button class="js-zeroclipboard btn btn-sm zeroclipboard-button tooltipped tooltipped-s" type="button" data-copied-hint="Copied!" aria-label="Copy to clipboard">
#
# <span class="octicon octicon-clippy"></span>
#
# </button>
#
# </span>
#
# </div>
#
# </div>
#
# <div class="clone-options">
#
# You can clone with
#
# <form class="inline-form js-clone-selector-form is-enabled" method="post" data-remote="true" data-form-nonce="6c29b689486a15ac6a50719013b85362efbebad2" action="/users/set_protocol?protocol_selector=http&protocol_type=clone" accept-charset="UTF-8">
#
# <div style="margin:0;padding:0;display:inline">
#
# <input type="hidden" value="✓" name="utf8">
#
# <input type="hidden" value="GN1dC24nuqeFSAMzV4uAk9PiDBFLWs3L2dB+dFV4LTE9WSjxVFBrcv2u1Yd/ATmTGLxoA6eduGshW3QtjdPlxQ==" name="authenticity_token">
#
# </div>
#
# <button class="btn-link js-clone-selector" type="submit" data-protocol="http">HTTPS</button>
#
# </form>
#
# ,
#
# <form class="inline-form js-clone-selector-form is-enabled" method="post" data-remote="true" data-form-nonce="6c29b689486a15ac6a50719013b85362efbebad2" action="/users/set_protocol?protocol_selector=ssh&protocol_type=clone" accept-charset="UTF-8">
#
# <div style="margin:0;padding:0;display:inline">
#
# <input type="hidden" value="✓" name="utf8">
#
# <input type="hidden" value="MyEc428A8aTextDahCKWSbyslHvtcnVbbN3+yvU7ngwJz1nDPnGEhM53h37RFJzafzNIX/+OVz/+NXMmDSu/TA==" name="authenticity_token">
#
# </div>
#
# <button class="btn-link js-clone-selector" type="submit" data-protocol="ssh">SSH</button>
#
# </form>
#
# , or
#
# <form class="inline-form js-clone-selector-form is-enabled" method="post" data-remote="true" data-form-nonce="6c29b689486a15ac6a50719013b85362efbebad2" action="/users/set_protocol?protocol_selector=subversion&protocol_type=clone" accept-charset="UTF-8">
#
# <div style="margin:0;padding:0;display:inline">
#
# <input type="hidden" value="✓" name="utf8">
#
# <input type="hidden" value="ohXKx6Oca4eJXRbkoKJ7BPs2Z4mN5gvE3dXP4Ku4KM92QDwqMjBCeChioSIGcVONrICzZSzN5LSv9ggN8nnn/w==" name="authenticity_token">
#
# </div>
#
# <button class="btn-link js-clone-selector" type="submit" data-protocol="subversion">Subversion</button>
#
# </form>
#
# .
#
# <a class="help tooltipped tooltipped-n" aria-label="Get help on which URL is right for you." href="https://help.github.com/articles/which-remote-url-should-i-use">
#
# <span class="octicon octicon-question"></span>
#
# </a>
#
# </div>
#
# <a class="btn btn-sm sidebar-button" aria-label="Save facebook/osquery to your computer and use it in GitHub Desktop." title="Save facebook/osquery to your computer and use it in GitHub Desktop." href="github-mac://openRepo/https://github.com/facebook/osquery">
#
# <span class="octicon octicon-desktop-download"></span>
#
# Clone in Desktop
#
# </a>
#
# <a class="btn btn-sm sidebar-button" rel="nofollow" title="Download the contents of facebook/osquery as a zip file" aria-label="Download the contents of facebook/osquery as a zip file" href="/facebook/osquery/archive/master.zip">
#
# <span class="octicon octicon-cloud-download"></span>
#
# Download ZIP
#
# </a>
#
# </div>
#
# </div>
#
# <div id="js-repo-pjax-container" class="repository-content context-loader-container" data-pjax-container="">
#
# <div class="tabnav" role="navigation">
#
# <nav class="tabnav-tabs" data-pjax="">
#
# <a class="js-selected-navigation-item selected tabnav-tab" role="tab" data-selected-links=" /facebook/osquery/graphs/contributors" aria-selected="true" href="/facebook/osquery/graphs/contributors">Contributors</a>
#
# <a class="js-selected-navigation-item tabnav-tab" role="tab" data-selected-links=" /facebook/osquery/graphs/commit-activity" href="/facebook/osquery/graphs/commit-activity">Commits</a>
#
# <a class="js-selected-navigation-item tabnav-tab" role="tab" data-selected-links=" /facebook/osquery/graphs/code-frequency" href="/facebook/osquery/graphs/code-frequency">Code frequency</a>
#
# <a class="js-selected-navigation-item tabnav-tab" role="tab" data-selected-links=" /facebook/osquery/graphs/punch-card" href="/facebook/osquery/graphs/punch-card">Punch card</a>
#
# <a class="js-selected-navigation-item tabnav-tab" role="tab" data-selected-links=" /facebook/osquery/network" href="/facebook/osquery/network">Network</a>
#
# <a class="js-selected-navigation-item tabnav-tab" role="tab" data-selected-links=" /facebook/osquery/network/members" href="/facebook/osquery/network/members">Members</a>
#
# </nav>
#
# </div>
#
# <div class="graph-filter clearfix">
#
# <div class="select-menu right js-menu-container js-select-menu js-contribution-container">
#
# <span class="btn btn-sm select-menu-button js-menu-target" aria-haspopup="true" role="button">
#
# <i>Contributions:</i>
#
# <span class="js-select-button">Commits</span>
#
# </span>
#
# <div class="select-menu-modal-holder js-menu-content js-navigation-container" aria-hidden="true">
#
# <div class="select-menu-modal">
#
# <div class="select-menu-header">
#
# <span class="select-menu-title">Filter contributions</span>
#
# <span class="octicon octicon-x js-menu-close" aria-label="Close" role="button"></span>
#
# </div>
#
# <div class="select-menu-list">
#
# <div class="select-menu-item js-navigation-item ">
#
# <input id="ctype_a" type="radio" value="a" name="ctype">
#
# <span class="select-menu-item-icon octicon octicon-check"></span>
#
# <div class="select-menu-item-text js-select-button-text">Additions</div>
#
# </div>
#
# <div class="select-menu-item js-navigation-item ">
#
# <input id="ctype_d" type="radio" value="d" name="ctype">
#
# <span class="select-menu-item-icon octicon octicon-check"></span>
#
# <div class="select-menu-item-text js-select-button-text">Deletions</div>
#
# </div>
#
# <div class="select-menu-item js-navigation-item selected">
#
# <input id="ctype_c" type="radio" value="c" name="ctype" checked="checked">
#
# <span class="select-menu-item-icon octicon octicon-check"></span>
#
# <div class="select-menu-item-text js-select-button-text">Commits</div>
#
# </div>
#
# </div>
#
# </div>
#
# </div>
#
# </div>
#
# <h3 class="js-date-range">Jul 27, 2014 – Sep 8, 2015</h3>
#
# <p class="info">Contributions to master, excluding merge commits</p>
#
# </div>
#
# <div class="graphs" data-repo-url="https://github.com/facebook/osquery">
#
# <div id="contributors-master" class="tint-box">
#
# <svg class="viz" height="175" width="920">
#
# <g transform="translate(50,20)">
#
# <g class="x axis" transform="translate(0, 125)">
#
# <g class="tick" style="opacity: 1;" transform="translate(10.76388888888889,0)">
#
# <line y2="6" x2="0">
#
# <text y="9" x="0" dy=".71em" style="text-anchor: middle;">August</text>
#
# </g>
#
# <g class="tick" style="opacity: 1;" transform="translate(75.34722222222223,0)">
#
# <line y2="6" x2="0">
#
# <text y="9" x="0" dy=".71em" style="text-anchor: middle;">September</text>
#
# </g>
#
# <g class="tick" style="opacity: 1;" transform="translate(137.84722222222223,0)">
#
# <line y2="6" x2="0">
#
# <text y="9" x="0" dy=".71em" style="text-anchor: middle;">October</text>
#
# </g>
#
# <g class="tick" style="opacity: 1;" transform="translate(202.43055555555557,0)">
#
# <line y2="6" x2="0">
#
# <text y="9" x="0" dy=".71em" style="text-anchor: middle;">November</text>
#
# </g>
#
# <g class="tick" style="opacity: 1;" transform="translate(265.0173611111111,0)">
#
# <line y2="6" x2="0">
#
# <text y="9" x="0" dy=".71em" style="text-anchor: middle;">December</text>
#
# </g>
#
# <g class="tick" style="opacity: 1;" transform="translate(329.60069444444446,0)">
#
# <line y2="6" x2="0">
#
# <text y="9" x="0" dy=".71em" style="text-anchor: middle;">2015</text>
#
# </g>
#
# <g class="tick" style="opacity: 1;" transform="translate(394.18402777777777,0)">
#
# <line y2="6" x2="0">
#
# <text y="9" x="0" dy=".71em" style="text-anchor: middle;">February</text>
#
# </g>
#
# <g class="tick" style="opacity: 1;" transform="translate(452.51736111111114,0)">
#
# <line y2="6" x2="0">
#
# <text y="9" x="0" dy=".71em" style="text-anchor: middle;">March</text>
#
# </g>
#
# <g class="tick" style="opacity: 1;" transform="translate(517.0138888888889,0)">
#
# <line y2="6" x2="0">
#
# <text y="9" x="0" dy=".71em" style="text-anchor: middle;">April</text>
#
# </g>
#
# <g class="tick" style="opacity: 1;" transform="translate(579.5138888888889,0)">
#
# <line y2="6" x2="0">
#
# <text y="9" x="0" dy=".71em" style="text-anchor: middle;">May</text>
#
# </g>
#
# <g class="tick" style="opacity: 1;" transform="translate(644.0972222222223,0)">
#
# <line y2="6" x2="0">
#
# <text y="9" x="0" dy=".71em" style="text-anchor: middle;">June</text>
#
# </g>
#
# <g class="tick" style="opacity: 1;" transform="translate(706.5972222222223,0)">
#
# <line y2="6" x2="0">
#
# <text y="9" x="0" dy=".71em" style="text-anchor: middle;">July</text>
#
# </g>
#
# <g class="tick" style="opacity: 1;" transform="translate(771.1805555555555,0)">
#
# <line y2="6" x2="0">
#
# <text y="9" x="0" dy=".71em" style="text-anchor: middle;">August</text>
#
# </g>
#
# <g class="tick" style="opacity: 1;" transform="translate(835.7638888888889,0)">
#
# <line y2="6" x2="0">
#
# <text y="9" x="0" dy=".71em" style="text-anchor: middle;">September</text>
#
# </g>
#
# <path class="domain" d="M0,6V0H850V6">
#
# </g>
#
# <g class="y axis">
#
# <g class="tick" style="opacity: 1;" transform="translate(0,125)">
#
# <line x2="850" y2="0">
#
# <text x="-10" y="0" dy=".32em" style="text-anchor: end;">0</text>
#
# </g>
#
# <g class="tick" style="opacity: 1;" transform="translate(0,91.21621621621622)">
#
# <line x2="850" y2="0">
#
# <text x="-10" y="0" dy=".32em" style="text-anchor: end;">20</text>
#
# </g>
#
# <g class="tick" style="opacity: 1;" transform="translate(0,57.432432432432435)">
#
# <line x2="850" y2="0">
#
# <text x="-10" y="0" dy=".32em" style="text-anchor: end;">40</text>
#
# </g>
#
# <g class="tick" style="opacity: 1;" transform="translate(0,23.648648648648646)">
#
# <line x2="850" y2="0">
#
# <text x="-10" y="0" dy=".32em" style="text-anchor: end;">60</text>
#
# </g>
#
# <path class="domain" d="M850,0H0V125H850">
#
# </g>
#
# <path class="area" d="M0,116.55405405405405L2.4305555555555554,106.98198198198197C4.861111111111111,97.4099099099099,9.722222222222221,78.26576576576576,14.583333333333332,70.94594594594594C19.444444444444443,63.62612612612612,24.305555555555554,68.13063063063062,29.166666666666668,73.76126126126125C34.02777777777778,79.39189189189187,38.88888888888889,86.14864864864865,43.75000000000001,81.08108108108107C48.611111111111114,76.0135135135135,53.47222222222222,59.121621621621614,58.333333333333336,56.3063063063063C63.194444444444...,87.5,124.99999999999999C82.6388888888889,125,77.77777777777779,125,72.91666666666667,124.99999999999999C68.05555555555556,125,63.19444444444444,125,58.33333333333333,124.99999999999999C53.47222222222222,125,48.611111111111114,125,43.75,124.99999999999999C38.88888888888889,125,34.02777777777778,125,29.166666666666664,124.99999999999999C24.305555555555554,125,19.444444444444443,125,14.583333333333332,124.99999999999999C9.722222222222221,125,4.861111111111111,125,2.4305555555555554,124.99999999999999L0,125Z">
#
# <g class="selection" style="pointer-events: all;">
#
# <rect class="background" style="visibility: hidden; cursor: crosshair;" x="0" width="850" height="125">
#
# <rect class="extent" style="cursor: move;" x="0" width="0" height="125">
#
# <g class="resize e" style="cursor: ew-resize; display: none;" transform="translate(0,0)">
#
# <rect x="-3" width="6" height="125" style="visibility: hidden;">
#
# </g>
#
# <g class="resize w" style="cursor: ew-resize; display: none;" transform="translate(0,0)">
#
# <rect x="-3" width="6" height="125" style="visibility: hidden;">
#
# </g>
#
# </g>
#
# </g>
#
# </svg>
#
# </div>
#
# <div id="contributors" class="clearfix js-graph graph-canvas" data-url="/facebook/osquery/graphs/contributors-data" data-graph-width="428">
#
# <div class="activity">
#
# <img class="graph-loading dots" width="64" alt="" src="https://assets-cdn.github.com/images/spinners/octocat-spinner-128.gif">
#
# <p class="graph-loading msg"> Crunching the latest data, just for you. Hang tight… </p>
#
# <p class="graph-empty msg"> We don’t have enough data to show you anything useful. It usually takes about a week to populate this graph with interesting data. </p>
#
# <p class="graph-no-usable-data msg"> No available data. We need at least one non-empty commit with an email to generate this graph. </p>
#
# </div>
#
# <div class="graph-error error"> We tried our best, but the graph wouldn’t load. Try reloading the page. </div>
#
# <ol class="contrib-data capped-cards clearfix">
#
# <li class="capped-card" style="display: block;">
#
# <h3>
#
# <img class="avatar" src="https://avatars0.githubusercontent.com/u/981645?v=3&s=60" alt="">
#
# <span class="rank">#1</span>
#
# <a class="aname" href="/theopolis">theopolis</a>
#
# <span class="ameta">
#
# <span class="cmeta">
#
# <a class="cmt" href="https://github.com/facebook/osquery/commits?author=theopolis">553 commits</a>
#
# /
#
# <span class="a">82,460 ++</span>
#
# /
#
# <span class="d">77,685 --</span>
#
# </span>
#
# </span>
#
# </h3>
#
# <svg class="capped-card-content" width="448" height="130">
#
# <g transform="translate(10,10)">
#
# <g class="x axis dense" transform="translate(0, 70)">
#
# <g class="tick" style="opacity: 1;" transform="translate(5.419934640522876,0)">
#
# <line y2="6" x2="0">
#
# <text y="9" x="0" dy=".71em" style="text-anchor: middle; display: block;" dx="7">August</text>
#
# </g>
#
# <g class="tick" style="opacity: 1;" transform="translate(37.939542483660134,0)">
#
# <line y2="6" x2="0">
#
# <text y="9" x="0" dy=".71em" style="text-anchor: middle; display: none;">September</text>
#
# </g>
#
# <g class="tick" style="opacity: 1;" transform="translate(69.41013071895425,0)">
#
# <line y2="6" x2="0">
#
# <text y="9" x="0" dy=".71em" style="text-anchor: middle; display: block;">October</text>
#
# </g>
#
# <g class="tick" style="opacity: 1;" transform="translate(101.92973856209152,0)">
#
# <line y2="6" x2="0">
#
# <text y="9" x="0" dy=".71em" style="text-anchor: middle; display: none;">November</text>
#
# </g>
#
# <g class="tick" style="opacity: 1;" transform="translate(133.44403594771242,0)">
#
# <line y2="6" x2="0">
#
# <text y="9" x="0" dy=".71em" style="text-anchor: middle; display: block;">December</text>
#
# </g>
#
# <g class="tick" style="opacity: 1;" transform="translate(165.9636437908497,0)">
#
# <line y2="6" x2="0">
#
# <text y="9" x="0" dy=".71em" style="text-anchor: middle; display: none;">2015</text>
#
# </g>
#
# <g class="tick" style="opacity: 1;" transform="translate(198.48325163398692,0)">
#
# <line y2="6" x2="0">
#
# <text y="9" x="0" dy=".71em" style="text-anchor: middle; display: block;">February</text>
#
# </g>
#
# <g class="tick" style="opacity: 1;" transform="translate(227.8558006535948,0)">
#
# <line y2="6" x2="0">
#
# <text y="9" x="0" dy=".71em" style="text-anchor: middle; display: none;">March</text>
#
# </g>
#
# <g class="tick" style="opacity: 1;" transform="translate(260.33169934640523,0)">
#
# <line y2="6" x2="0">
#
# <text y="9" x="0" dy=".71em" style="text-anchor: middle; display: block;">April</text>
#
# </g>
#
# <g class="tick" style="opacity: 1;" transform="translate(291.8022875816994,0)">
#
# <line y2="6" x2="0">
#
# <text y="9" x="0" dy=".71em" style="text-anchor: middle; display: none;">May</text>
#
# </g>
#
# <g class="tick" style="opacity: 1;" transform="translate(324.3218954248366,0)">
#
# <line y2="6" x2="0">
#
# <text y="9" x="0" dy=".71em" style="text-anchor: middle; display: block;">June</text>
#
# </g>
#
# <g class="tick" style="opacity: 1;" transform="translate(355.79248366013076,0)">
#
# <line y2="6" x2="0">
#
# <text y="9" x="0" dy=".71em" style="text-anchor: middle; display: none;">July</text>
#
# </g>
#
# <g class="tick" style="opacity: 1;" transform="translate(388.312091503268,0)">
#
# <line y2="6" x2="0">
#
# <text y="9" x="0" dy=".71em" style="text-anchor: middle; display: block;">August</text>
#
# </g>
#
# <g class="tick" style="opacity: 1;" transform="translate(420.83169934640523,0)">
#
# <line y2="6" x2="0">
#
# <text y="9" x="0" dy=".71em" style="text-anchor: middle; display: none;">September</text>
#
# </g>
#
# <path class="domain" d="M0,6V0H428V6">
#
# </g>
#
# <g class="y axis">
#
# <g class="tick" style="opacity: 1;" transform="translate(0,70)">
#
# <line x2="428" y2="0">
#
# <text class="midlabel" x="-10" y="0" dy=".32em" style="text-anchor: end; display: none;" dx="214">0</text>
#
# </g>
#
# <g class="tick" style="opacity: 1;" transform="translate(0,42)">
#
# <line x2="428" y2="0">
#
# <text class="midlabel" x="-10" y="0" dy=".32em" style="text-anchor: end; display: block;" dx="214">20</text>
#
# </g>
#
# <g class="tick" style="opacity: 1;" transform="translate(0,14)">
#
# <line x2="428" y2="0">
#
# <text class="midlabel" x="-10" y="0" dy=".32em" style="text-anchor: end; display: block;" dx="214">40</text>
#
# </g>
#
# <path class="domain" d="M428,0H0V70H428">
#
# </g>
#
# <path d="M0,70L1.223856209150327,70C2.447712418300654,70,4.895424836601308,70,7.343137254901961,69.3C9.790849673202615,68.6,12.238562091503269,67.19999999999999,14.686274509803923,66.03333333333333C17.133986928104576,64.86666666666666,19.58169934640523,63.93333333333333,22.029411764705884,64.63333333333334C24.477124183006538,65.33333333333333,26.92483660130719,67.66666666666666,29.372549019607845,68.13333333333333C31.8202614379085,68.6,34.26797385620915,67.19999999999999,36.71568627450981,66.26666666666665C39.16339...38562091504,70,53.84967320261438,70,51.40196078431373,70C48.954248366013076,70,46.50653594771242,70,44.05882352941177,70C41.611111111111114,70,39.16339869281046,70,36.71568627450981,70C34.26797385620915,70,31.8202614379085,70,29.372549019607845,70C26.92483660130719,70,24.477124183006538,70,22.029411764705884,70C19.58169934640523,70,17.133986928104576,70,14.686274509803923,70C12.238562091503269,70,9.790849673202615,70,7.343137254901961,70C4.895424836601308,70,2.447712418300654,70,1.223856209150327,70L0,70Z">
#
# </g>
#
# </svg>
#
# </li>
#
# <li class="capped-card" style="display: block;">
#
# <h3>
#
# <img class="avatar" src="https://avatars0.githubusercontent.com/u/927168?v=3&s=60" alt="">
#
# <span class="rank">#2</span>
#
# <a class="aname" href="/marpaia">marpaia</a>
#
# <span class="ameta">
#
# <span class="cmeta">
#
# <a class="cmt" href="https://github.com/facebook/osquery/commits?author=marpaia">477 commits</a>
#
# /
#
# <span class="a">225,054 ++</span>
#
# /
#
# <span class="d">182,302 --</span>
#
# </span>
#
# </span>
#
# </h3>
#
# <svg class="capped-card-content" width="448" height="130">
#
# <g transform="translate(10,10)">
#
# <g class="x axis dense" transform="translate(0, 70)">
#
# <g class="tick" style="opacity: 1;" transform="translate(5.419934640522876,0)">
#
# <line y2="6" x2="0">
#
# <text y="9" x="0" dy=".71em" style="text-anchor: middle; display: block;" dx="7">August</text>
#
# </g>
#
# <g class="tick" style="opacity: 1;" transform="translate(37.939542483660134,0)">
#
# <line y2="6" x2="0">
#
# <text y="9" x="0" dy=".71em" style="text-anchor: middle; display: none;">September</text>
#
# </g>
#
# <g class="tick" style="opacity: 1;" transform="translate(69.41013071895425,0)">
#
# <line y2="6" x2="0">
#
# <text y="9" x="0" dy=".71em" style="text-anchor: middle; display: block;">October</text>
#
# </g>
#
# <g class="tick" style="opacity: 1;" transform="translate(101.92973856209152,0)">
#
# <line y2="6" x2="0">
#
# <text y="9" x="0" dy=".71em" style="text-anchor: middle; display: none;">November</text>
#
# </g>
#
# <g class="tick" style="opacity: 1;" transform="translate(133.44403594771242,0)">
#
# <line y2="6" x2="0">
#
# <text y="9" x="0" dy=".71em" style="text-anchor: middle; display: block;">December</text>
#
# </g>
#
# <g class="tick" style="opacity: 1;" transform="translate(165.9636437908497,0)">
#
# <line y2="6" x2="0">
#
# <text y="9" x="0" dy=".71em" style="text-anchor: middle; display: none;">2015</text>
#
# </g>
#
# <g class="tick" style="opacity: 1;" transform="translate(198.48325163398692,0)">
#
# <line y2="6" x2="0">
#
# <text y="9" x="0" dy=".71em" style="text-anchor: middle; display: block;">February</text>
#
# </g>
#
# <g class="tick" style="opacity: 1;" transform="translate(227.8558006535948,0)">
#
# <line y2="6" x2="0">
#
# <text y="9" x="0" dy=".71em" style="text-anchor: middle; display: none;">March</text>
#
# </g>
#
# <g class="tick" style="opacity: 1;" transform="translate(260.33169934640523,0)">
#
# <line y2="6" x2="0">
#
# <text y="9" x="0" dy=".71em" style="text-anchor: middle; display: block;">April</text>
#
# </g>
#
# <g class="tick" style="opacity: 1;" transform="translate(291.8022875816994,0)">
#
# <line y2="6" x2="0">
#
# <text y="9" x="0" dy=".71em" style="text-anchor: middle; display: none;">May</text>
#
# </g>
#
# <g class="tick" style="opacity: 1;" transform="translate(324.3218954248366,0)">
#
# <line y2="6" x2="0">
#
# <text y="9" x="0" dy=".71em" style="text-anchor: middle; display: block;">June</text>
#
# </g>
#
# <g class="tick" style="opacity: 1;" transform="translate(355.79248366013076,0)">
#
# <line y2="6" x2="0">
#
# <text y="9" x="0" dy=".71em" style="text-anchor: middle; display: none;">July</text>
#
# </g>
#
# <g class="tick" style="opacity: 1;" transform="translate(388.312091503268,0)">
#
# <line y2="6" x2="0">
#
# <text y="9" x="0" dy=".71em" style="text-anchor: middle; display: block;">August</text>
#
# </g>
#
# <g class="tick" style="opacity: 1;" transform="translate(420.83169934640523,0)">
#
# <line y2="6" x2="0">
#
# <text y="9" x="0" dy=".71em" style="text-anchor: middle; display: none;">September</text>
#
# </g>
#
# <path class="domain" d="M0,6V0H428V6">
#
# </g>
#
# <g class="y axis">
#
# <g class="tick" style="opacity: 1;" transform="translate(0,70)">
#
# <line x2="428" y2="0">
#
# <text class="midlabel" x="-10" y="0" dy=".32em" style="text-anchor: end; display: none;" dx="214">0</text>
#
# </g>
#
# <g class="tick" style="opacity: 1;" transform="translate(0,42)">
#
# <line x2="428" y2="0">
#
# <text class="midlabel" x="-10" y="0" dy=".32em" style="text-anchor: end; display: block;" dx="214">20</text>
#
# </g>
#
# <g class="tick" style="opacity: 1;" transform="translate(0,14)">
#
# <line x2="428" y2="0">
#
# <text class="midlabel" x="-10" y="0" dy=".32em" style="text-anchor: end; display: block;" dx="214">40</text>
#
# </g>
#
# <path class="domain" d="M428,0H0V70H428">
#
# </g>
#
# <path d="M0,63L1.223856209150327,55.06666666666666C2.447712418300654,47.13333333333333,4.895424836601308,31.266666666666666,7.343137254901961,25.9C9.790849673202615,20.53333333333333,12.238562091503269,25.666666666666664,14.686274509803923,31.499999999999996C17.133986928104576,37.33333333333333,19.58169934640523,43.86666666666666,22.029411764705884,38.96666666666666C24.477124183006538,34.06666666666666,26.92483660130719,17.733333333333334,29.372549019607845,15.400000000000002C31.8202614379085,13.06666666666667,34.2...38562091504,70,53.84967320261438,70,51.40196078431373,70C48.954248366013076,70,46.50653594771242,70,44.05882352941177,70C41.611111111111114,70,39.16339869281046,70,36.71568627450981,70C34.26797385620915,70,31.8202614379085,70,29.372549019607845,70C26.92483660130719,70,24.477124183006538,70,22.029411764705884,70C19.58169934640523,70,17.133986928104576,70,14.686274509803923,70C12.238562091503269,70,9.790849673202615,70,7.343137254901961,70C4.895424836601308,70,2.447712418300654,70,1.223856209150327,70L0,70Z">
#
# </g>
#
# </svg>
#
# </li>
#
# <li class="capped-card" style="display: block;">
#
# <h3>
#
# <img class="avatar" src="https://avatars0.githubusercontent.com/u/1271349?v=3&s=60" alt="">
#
# <span class="rank">#3</span>
#
# <a class="aname" href="/javuto">javuto</a>
#
# <span class="ameta">
#
# <span class="cmeta">
#
# <a class="cmt" href="https://github.com/facebook/osquery/commits?author=javuto">104 commits</a>
#
# /
#
# <span class="a">5,060 ++</span>
#
# /
#
# <span class="d">2,163 --</span>
#
# </span>
#
# </span>
#
# </h3>
#
# <svg class="capped-card-content" width="448" height="130">
#
# <g transform="translate(10,10)">
#
# <g class="x axis dense" transform="translate(0, 70)">
#
# <g class="tick" style="opacity: 1;" transform="translate(5.419934640522876,0)">
#
# <line y2="6" x2="0">
#
# <text y="9" x="0" dy=".71em" style="text-anchor: middle; display: block;" dx="7">August</text>
#
# </g>
#
# <g class="tick" style="opacity: 1;" transform="translate(37.939542483660134,0)">
#
# <line y2="6" x2="0">
#
# <text y="9" x="0" dy=".71em" style="text-anchor: middle; display: none;">September</text>
#
# </g>
#
# <g class="tick" style="opacity: 1;" transform="translate(69.41013071895425,0)">
#
# <line y2="6" x2="0">
#
# <text y="9" x="0" dy=".71em" style="text-anchor: middle; display: block;">October</text>
#
# </g>
#
# <g class="tick" style="opacity: 1;" transform="translate(101.92973856209152,0)">
#
# <line y2="6" x2="0">
#
# <text y="9" x="0" dy=".71em" style="text-anchor: middle; display: none;">November</text>
#
# </g>
#
# <g class="tick" style="opacity: 1;" transform="translate(133.44403594771242,0)">
#
# <line y2="6" x2="0">
#
# <text y="9" x="0" dy=".71em" style="text-anchor: middle; display: block;">December</text>
#
# </g>
#
# <g class="tick" style="opacity: 1;" transform="translate(165.9636437908497,0)">
#
# <line y2="6" x2="0">
#
# <text y="9" x="0" dy=".71em" style="text-anchor: middle; display: none;">2015</text>
#
# </g>
#
# <g class="tick" style="opacity: 1;" transform="translate(198.48325163398692,0)">
#
# <line y2="6" x2="0">
#
# <text y="9" x="0" dy=".71em" style="text-anchor: middle; display: block;">February</text>
#
# </g>
#
# <g class="tick" style="opacity: 1;" transform="translate(227.8558006535948,0)">
#
# <line y2="6" x2="0">
#
# <text y="9" x="0" dy=".71em" style="text-anchor: middle; display: none;">March</text>
#
# </g>
#
# <g class="tick" style="opacity: 1;" transform="translate(260.33169934640523,0)">
#
# <line y2="6" x2="0">
#
# <text y="9" x="0" dy=".71em" style="text-anchor: middle; display: block;">April</text>
#
# </g>
#
# <g class="tick" style="opacity: 1;" transform="translate(291.8022875816994,0)">
#
# <line y2="6" x2="0">
#
# <text y="9" x="0" dy=".71em" style="text-anchor: middle; display: none;">May</text>
#
# </g>
#
# ...
#
# </g>
#
# <g class="tick" style="opacity: 1;" transform="translate(0,42)">
#
# <line x2="428" y2="0">
#
# <text class="midlabel" x="-10" y="0" dy=".32em" style="text-anchor: end; display: block;" dx="214">20</text>
#
# </g>
#
# <g class="tick" style="opacity: 1;" transform="translate(0,14)">
#
# <line x2="428" y2="0">
#
# <text class="midlabel" x="-10" y="0" dy=".32em" style="text-anchor: end; display: block;" dx="214">40</text>
#
# </g>
#
# <path class="domain" d="M428,0H0V70H428">
#
# </g>
#
# <path d="M0,70L1.223856209150327,70C2.447712418300654,70,4.895424836601308,70,7.343137254901961,70C9.790849673202615,70,12.238562091503269,70,14.686274509803923,70C17.133986928104576,70,19.58169934640523,70,22.029411764705884,70C24.477124183006538,70,26.92483660130719,70,29.372549019607845,70C31.8202614379085,70,34.26797385620915,70,36.71568627450981,70C39.16339869281046,70,41.611111111111114,70,44.05882352941177,70C46.50653594771242,70,48.954248366013076,70,51.40196078431373,70C53.84967320261438,70,56.297385620915...38562091504,70,53.84967320261438,70,51.40196078431373,70C48.954248366013076,70,46.50653594771242,70,44.05882352941177,70C41.611111111111114,70,39.16339869281046,70,36.71568627450981,70C34.26797385620915,70,31.8202614379085,70,29.372549019607845,70C26.92483660130719,70,24.477124183006538,70,22.029411764705884,70C19.58169934640523,70,17.133986928104576,70,14.686274509803923,70C12.238562091503269,70,9.790849673202615,70,7.343137254901961,70C4.895424836601308,70,2.447712418300654,70,1.223856209150327,70L0,70Z">
#
# </g>
#
# </svg>
#
# </li>
#
# <li class="capped-card" style="display: block;">
#
# <h3>
#
# <img class="avatar" src="https://avatars3.githubusercontent.com/u/48211?v=3&s=60" alt="">
#
# <span class="rank">#58</span>
#
# <a class="aname" href="/d0ugal">d0ugal</a>
#
# <span class="ameta">
#
# <span class="cmeta">
#
# <a class="cmt" href="https://github.com/facebook/osquery/commits?author=d0ugal">1 commit</a>
#
# /
#
# <span class="a">32 ++</span>
#
# /
#
# <span class="d">31 --</span>
#
# </span>
#
# </span>
#
# </h3>
#
# <svg class="capped-card-content" width="448" height="130">
#
# <g transform="translate(10,10)">
#
# <g class="x axis dense" transform="translate(0, 70)">
#
# <g class="tick" style="opacity: 1;" transform="translate(5.419934640522876,0)">
#
# <line y2="6" x2="0">
#
# <text y="9" x="0" dy=".71em" style="text-anchor: middle; display: block;" dx="7">August</text>
#
# </g>
#
# <g class="tick" style="opacity: 1;" transform="translate(37.939542483660134,0)">
#
# <line y2="6" x2="0">
#
# <text y="9" x="0" dy=".71em" style="text-anchor: middle; display: none;">September</text>
#
# </g>
#
# <g class="tick" style="opacity: 1;" transform="translate(69.41013071895425,0)">
#
# <line y2="6" x2="0">
#
# <text y="9" x="0" dy=".71em" style="text-anchor: middle; display: block;">October</text>
#
# </g>
#
# <g class="tick" style="opacity: 1;" transform="translate(101.92973856209152,0)">
#
# <line y2="6" x2="0">
#
# <text y="9" x="0" dy=".71em" style="text-anchor: middle; display: none;">November</text>
#
# </g>
#
# <g class="tick" style="opacity: 1;" transform="translate(133.44403594771242,0)">
#
# <line y2="6" x2="0">
#
# <text y="9" x="0" dy=".71em" style="text-anchor: middle; display: block;">December</text>
#
# </g>
#
# <g class="tick" style="opacity: 1;" transform="translate(165.9636437908497,0)">
#
# <line y2="6" x2="0">
#
# <text y="9" x="0" dy=".71em" style="text-anchor: middle; display: none;">2015</text>
#
# </g>
#
# <g class="tick" style="opacity: 1;" transform="translate(198.48325163398692,0)">
#
# <line y2="6" x2="0">
#
# <text y="9" x="0" dy=".71em" style="text-anchor: middle; display: block;">February</text>
#
# </g>
#
# <g class="tick" style="opacity: 1;" transform="translate(227.8558006535948,0)">
#
# <line y2="6" x2="0">
#
# <text y="9" x="0" dy=".71em" style="text-anchor: middle; display: none;">March</text>
#
# </g>
#
# <g class="tick" style="opacity: 1;" transform="translate(260.33169934640523,0)">
#
# <line y2="6" x2="0">
#
# <text y="9" x="0" dy=".71em" style="text-anchor: middle; display: block;">April</text>
#
# </g>
#
# <g class="tick" style="opacity: 1;" transform="translate(291.8022875816994,0)">
#
# <line y2="6" x2="0">
#
# <text y="9" x="0" dy=".71em" style="text-anchor: middle; display: none;">May</text>
#
# </g>
#
# <g class="tick" style="opacity: 1;" transform="translate(324.3218954248366,0)">
#
# <line y2="6" x2="0">
#
# <text y="9" x="0" dy=".71em" style="text-anchor: middle; display: block;">June</text>
#
# </g>
#
# <g class="tick" style="opacity: 1;" transform="translate(355.79248366013076,0)">
#
# <line y2="6" x2="0">
#
# <text y="9" x="0" dy=".71em" style="text-anchor: middle; display: none;">July</text>
#
# </g>
#
# <g class="tick" style="opacity: 1;" transform="translate(388.312091503268,0)">
#
# <line y2="6" x2="0">
#
# <text y="9" x="0" dy=".71em" style="text-anchor: middle; display: block;">August</text>
#
# </g>
#
# <g class="tick" style="opacity: 1;" transform="translate(420.83169934640523,0)">
#
# <line y2="6" x2="0">
#
# <text y="9" x="0" dy=".71em" style="text-anchor: middle; display: none;">September</text>
#
# </g>
#
# <path class="domain" d="M0,6V0H428V6">
#
# </g>
#
# <g class="y axis">
#
# <g class="tick" style="opacity: 1;" transform="translate(0,70)">
#
# <line x2="428" y2="0">
#
# <text class="midlabel" x="-10" y="0" dy=".32em" style="text-anchor: end; display: none;" dx="214">0</text>
#
# </g>
#
# <g class="tick" style="opacity: 1;" transform="translate(0,42)">
#
# <line x2="428" y2="0">
#
# <text class="midlabel" x="-10" y="0" dy=".32em" style="text-anchor: end; display: block;" dx="214">20</text>
#
# </g>
#
# <g class="tick" style="opacity: 1;" transform="translate(0,14)">
#
# <line x2="428" y2="0">
#
# <text class="midlabel" x="-10" y="0" dy=".32em" style="text-anchor: end; display: block;" dx="214">40</text>
#
# </g>
#
# <path class="domain" d="M428,0H0V70H428">
#
# </g>
#
# <path d="M0,70L1.223856209150327,70C2.447712418300654,70,4.895424836601308,70,7.343137254901961,70C9.790849673202615,70,12.238562091503269,70,14.686274509803923,70C17.133986928104576,70,19.58169934640523,70,22.029411764705884,70C24.477124183006538,70,26.92483660130719,70,29.372549019607845,70C31.8202614379085,70,34.26797385620915,70,36.71568627450981,70C39.16339869281046,70,41.611111111111114,70,44.05882352941177,70C46.50653594771242,70,48.954248366013076,70,51.40196078431373,70C53.84967320261438,70,56.297385620915...38562091504,70,53.84967320261438,70,51.40196078431373,70C48.954248366013076,70,46.50653594771242,70,44.05882352941177,70C41.611111111111114,70,39.16339869281046,70,36.71568627450981,70C34.26797385620915,70,31.8202614379085,70,29.372549019607845,70C26.92483660130719,70,24.477124183006538,70,22.029411764705884,70C19.58169934640523,70,17.133986928104576,70,14.686274509803923,70C12.238562091503269,70,9.790849673202615,70,7.343137254901961,70C4.895424836601308,70,2.447712418300654,70,1.223856209150327,70L0,70Z">
#
# </g>
#
# </svg>
#
# </li>
#
# <li class="capped-card" style="display: block;">
#
# <h3>
#
# <img class="avatar" src="https://avatars3.githubusercontent.com/u/6180644?v=3&s=60" alt="">
#
# <span class="rank">#59</span>
#
# <a class="aname" href="/stevenhilder">stevenhilder</a>
#
# <span class="ameta">
#
# <span class="cmeta">
#
# <a class="cmt" href="https://github.com/facebook/osquery/commits?author=stevenhilder">1 commit</a>
#
# /
#
# <span class="a">1 ++</span>
#
# /
#
# <span class="d">1 --</span>
#
# </span>
#
# </span>
#
# </h3>
#
# <svg class="capped-card-content" width="448" height="130">
#
# <g transform="translate(10,10)">
#
# <g class="x axis dense" transform="translate(0, 70)">
#
# <g class="tick" style="opacity: 1;" transform="translate(5.419934640522876,0)">
#
# <line y2="6" x2="0">
#
# <text y="9" x="0" dy=".71em" style="text-anchor: middle; display: block;" dx="7">August</text>
#
# </g>
#
# <g class="tick" style="opacity: 1;" transform="translate(37.939542483660134,0)">
#
# <line y2="6" x2="0">
#
# <text y="9" x="0" dy=".71em" style="text-anchor: middle; display: none;">September</text>
#
# </g>
#
# <g class="tick" style="opacity: 1;" transform="translate(69.41013071895425,0)">
#
# <line y2="6" x2="0">
#
# <text y="9" x="0" dy=".71em" style="text-anchor: middle; display: block;">October</text>
#
# </g>
#
# <g class="tick" style="opacity: 1;" transform="translate(101.92973856209152,0)">
#
# <line y2="6" x2="0">
#
# <text y="9" x="0" dy=".71em" style="text-anchor: middle; display: none;">November</text>
#
# </g>
#
# <g class="tick" style="opacity: 1;" transform="translate(133.44403594771242,0)">
#
# <line y2="6" x2="0">
#
# <text y="9" x="0" dy=".71em" style="text-anchor: middle; display: block;">December</text>
#
# </g>
#
# <g class="tick" style="opacity: 1;" transform="translate(165.9636437908497,0)">
#
# <line y2="6" x2="0">
#
# <text y="9" x="0" dy=".71em" style="text-anchor: middle; display: none;">2015</text>
#
# </g>
#
# <g class="tick" style="opacity: 1;" transform="translate(198.48325163398692,0)">
#
# <line y2="6" x2="0">
#
# <text y="9" x="0" dy=".71em" style="text-anchor: middle; display: block;">February</text>
#
# </g>
#
# <g class="tick" style="opacity: 1;" transform="translate(227.8558006535948,0)">
#
# <line y2="6" x2="0">
#
# <text y="9" x="0" dy=".71em" style="text-anchor: middle; display: none;">March</text>
#
# </g>
#
# <g class="tick" style="opacity: 1;" transform="translate(260.33169934640523,0)">
#
# <line y2="6" x2="0">
#
# <text y="9" x="0" dy=".71em" style="text-anchor: middle; display: block;">April</text>
#
# </g>
#
# <g class="tick" style="opacity: 1;" transform="translate(291.8022875816994,0)">
#
# <line y2="6" x2="0">
#
# <text y="9" x="0" dy=".71em" style="text-anchor: middle; display: none;">May</text>
#
# </g>
#
# <g class="tick" style="opacity: 1;" transform="translate(324.3218954248366,0)">
#
# <line y2="6" x2="0">
#
# <text y="9" x="0" dy=".71em" style="text-anchor: middle; display: block;">June</text>
#
# </g>
#
# <g class="tick" style="opacity: 1;" transform="translate(355.79248366013076,0)">
#
# <line y2="6" x2="0">
#
# <text y="9" x="0" dy=".71em" style="text-anchor: middle; display: none;">July</text>
#
# </g>
#
# <g class="tick" style="opacity: 1;" transform="translate(388.312091503268,0)">
#
# <line y2="6" x2="0">
#
# <text y="9" x="0" dy=".71em" style="text-anchor: middle; display: block;">August</text>
#
# </g>
#
# <g class="tick" style="opacity: 1;" transform="translate(420.83169934640523,0)">
#
# <line y2="6" x2="0">
#
# <text y="9" x="0" dy=".71em" style="text-anchor: middle; display: none;">September</text>
#
# </g>
#
# <path class="domain" d="M0,6V0H428V6">
#
# </g>
#
# <g class="y axis">
#
# <g class="tick" style="opacity: 1;" transform="translate(0,70)">
#
# <line x2="428" y2="0">
#
# <text class="midlabel" x="-10" y="0" dy=".32em" style="text-anchor: end; display: none;" dx="214">0</text>
#
# </g>
#
# <g class="tick" style="opacity: 1;" transform="translate(0,42)">
#
# <line x2="428" y2="0">
#
# <text class="midlabel" x="-10" y="0" dy=".32em" style="text-anchor: end; display: block;" dx="214">20</text>
#
# </g>
#
# <g class="tick" style="opacity: 1;" transform="translate(0,14)">
#
# <line x2="428" y2="0">
#
# <text class="midlabel" x="-10" y="0" dy=".32em" style="text-anchor: end; display: block;" dx="214">40</text>
#
# </g>
#
# <path class="domain" d="M428,0H0V70H428">
#
# </g>
#
# <path d="M0,70L1.223856209150327,70C2.447712418300654,70,4.895424836601308,70,7.343137254901961,70C9.790849673202615,70,12.238562091503269,70,14.686274509803923,70C17.133986928104576,70,19.58169934640523,70,22.029411764705884,70C24.477124183006538,70,26.92483660130719,70,29.372549019607845,70C31.8202614379085,70,34.26797385620915,70,36.71568627450981,70C39.16339869281046,70,41.611111111111114,70,44.05882352941177,70C46.50653594771242,70,48.954248366013076,70,51.40196078431373,70C53.84967320261438,70,56.297385620915...38562091504,70,53.84967320261438,70,51.40196078431373,70C48.954248366013076,70,46.50653594771242,70,44.05882352941177,70C41.611111111111114,70,39.16339869281046,70,36.71568627450981,70C34.26797385620915,70,31.8202614379085,70,29.372549019607845,70C26.92483660130719,70,24.477124183006538,70,22.029411764705884,70C19.58169934640523,70,17.133986928104576,70,14.686274509803923,70C12.238562091503269,70,9.790849673202615,70,7.343137254901961,70C4.895424836601308,70,2.447712418300654,70,1.223856209150327,70L0,70Z">
#
# </g>
#
# </svg>
#
# </li>
#
# </ol>
#
# </div>
#
# </div>
#
# </div>
#
# </div>
#
# <div class="modal-backdrop"></div>
#
# </div>
#
# </div>
#
# <div class="container">
#
# <div class="site-footer" role="contentinfo">
#
# <ul class="site-footer-links right">
#
# <li>
#
# <a data-ga-click="Footer, go to status, text:status" href="https://status.github.com/">Status</a>
#
# </li>
#
# <li>
#
# <a data-ga-click="Footer, go to api, text:api" href="https://developer.github.com">API</a>
#
# </li>
#
# <li>
#
# <a data-ga-click="Footer, go to training, text:training" href="https://training.github.com">Training</a>
#
# </li>
#
# <li>
#
# <a data-ga-click="Footer, go to shop, text:shop" href="https://shop.github.com">Shop</a>
#
# </li>
#
# <li>
#
# <a data-ga-click="Footer, go to blog, text:blog" href="https://github.com/blog">Blog</a>
#
# </li>
#
# <li>
#
# <a data-ga-click="Footer, go to about, text:about" href="https://github.com/about">About</a>
#
# </li>
#
# <li>
#
# <a data-ga-click="Footer, go to pricing, text:pricing" href="https://github.com/pricing">Pricing</a>
#
# </li>
#
# </ul>
#
# <a aria-label="Homepage" href="https://github.com">
#
# <span class="mega-octicon octicon-mark-github" title="GitHub"></span>
#
# </a>
#
# <ul class="site-footer-links">
#
# <li>
#
# © 2015
#
# <span title="0.06683s from github-fe138-cp1-prd.iad.github.net">GitHub</span>
#
# , Inc.
#
# </li>
#
# <li>
#
# <a data-ga-click="Footer, go to terms, text:terms" href="https://github.com/site/terms">Terms</a>
#
# </li>
#
# <li>
#
# <a data-ga-click="Footer, go to privacy, text:privacy" href="https://github.com/site/privacy">Privacy</a>
#
# </li>
#
# <li>
#
# <a data-ga-click="Footer, go to security, text:security" href="https://github.com/security">Security</a>
#
# </li>
#
# <li>
#
# <a data-ga-click="Footer, go to contact, text:contact" href="https://github.com/contact">Contact</a>
#
# </li>
#
# <li>
#
# <a data-ga-click="Footer, go to help, text:help" href="https://help.github.com">Help</a>
#
# </li>
#
# </ul>
#
# </div>
#
# </div>
#
# <div id="ajax-error-message" class="flash flash-error">
#
# <span class="octicon octicon-alert"></span>
#
# <button class="flash-close js-flash-close js-ajax-error-dismiss" aria-label="Dismiss error" type="button">
#
# <span class="octicon octicon-x"></span>
#
# </button>
#
# Something went wrong with that request. Please try again.
#
# </div>
#
# <script src="https://assets-cdn.github.com/assets/frameworks-06e65f5639cc52d1aaada53115a54614b60fa90ab446a673e3e1818df167663b.js" crossorigin="anonymous">
#
# <script src="https://assets-cdn.github.com/assets/github-6486b386f2ea8e61e35e6f68b6e5506fa17aed1c385b528ece57088cf14a1459.js" crossorigin="anonymous" async="async">
#
# <div class="js-stale-session-flash stale-session-flash flash flash-warn flash-banner hidden">
#
# <span class="octicon octicon-alert"></span>
#
# <span class="signed-in-tab-flash">
#
# You signed in with another tab or window.
#
# <a href="">Reload</a>
#
# to refresh your session.
#
# </span>
#
# <span class="signed-out-tab-flash">
#
# You signed out in another tab or window.
#
# <a href="">Reload</a>
#
# to refresh your session.
#
# </span>
#
# </div>
#
# <div id="global-zeroclipboard-html-bridge" class="global-zeroclipboard-container" style="position: absolute; left: 0px; top: -9999px; width: 1px; height: 1px; z-index: 999999999;">
#
# <object id="global-zeroclipboard-flash-bridge" width="100%" height="100%" data="https://assets-cdn.github.com/flash/ZeroClipboard.v2.1.6.swf" type="application/x-shockwave-flash" name="global-zeroclipboard-flash-bridge">
#
# <param value="always" name="allowScriptAccess">
#
# <param value="all" name="allowNetworking">
#
# <param value="false" name="menu">
#
# <param value="transparent" name="wmode">
#
# <param value="trustedOrigins=github.com%2C%2F%2Fgithub.com%2Chttps%3A%2F%2Fgithub.com&swfObjectId=global-zeroclipboard-flash-bridge" name="flashvars">
#
# </object>
#
# </div>
#
# <div id="facebox" class="facebox" style="display:none;">
#
# <div class="facebox-popup">
#
# <div class="facebox-content" aria-describedby="facebox-description" aria-labelledby="facebox-header" role="dialog"> </div>
#
# <button class="facebox-close js-facebox-close" aria-label="Close modal" type="button">
#
# <span class="octicon octicon-remove-close"></span>
#
# </button>
#
# </div>
#
# </div>
#
# </body>
#
# </html>

# %% [markdown]
# https://developers.google.com/edu/python/regular-expressions: useful introduction to regular expressions!

# %% [markdown]
# match = re.search(pat, str)

# %%
str = 'an example word:cat!!'
match = re.search('word:\w\w\w', str)

# %%
# If-statement after search() tests if it succeeded
if match:                      
    print('found', match.group())

# %%
## Search for pattern 'iii' in string 'piiig'.
## All of the pattern must match, but it may appear anywhere.
## On success, match.group() is matched text.
match = re.search('iii', 'piiig')

# %%
match.group()

# %%
match = re.search('igs', 'piiig') 
match.group()

# %%
## . = any char but \n
match = re.search('..g', 'piiig') 
match.group()

# %%
## \d = digit char, \w = word char
match = re.search('\d\d\d', 'p123g')
match.group()

# %%
match = re.search('\w\w\w', '@@abcd!!')
match.group()

# %%
  ## i+ = one or more i's, as many as possible.


match = re.search('pi+', 'piiig')
match.group()

# %%
## Finds the first/leftmost solution, and within it drives the +
  ## as far as possible (aka 'leftmost and largest').
  ## In this example, note that it does not get to the second set of i's.

match = re.search('i+', 'piigiiii')

# %%
## \s* = zero or more whitespace chars
  ## Here look for 3 digits, possibly separated by whitespace.
match = re.search('\d\s*\d\s*\d', 'xx1 2   3xx')

# %%
match = re.search('\d\s*\d\s*\d', 'xx12  3xx')

# %%
match = re.search('\d\s*\d\s*\d', 'xx123xx')

# %%
## ^ = matches the start of string, so this fails:
match = re.search('^b\w+', 'foobar')

# %%
## but without the ^ it succeeds:
match = re.search('b\w+', 'foobar')
match.group()

# %%
str = 'purple alice-b@google.com monkey dishwasher'
match = re.search( %Insert code here%%, str)

# %%
str = 'purple alice-b@google.com monkey dishwasher'
match = re.search('([\w.-]+)@([\w.-]+)', str)

# %%
match.group()
